# %% [markdown]
# It is the file showing different arihtmetic operations and compare function in python pandas.

# %%
import pandas as pd

var= pd.DataFrame({"a":[1,2,3,4], "b":[5,6,7,8]})
var
# Out:
#    a  b
# 0  1  5
# 1  2  6
# 2  3  7
# 3  4  8

# %%
var["c"]= var["a"]+var["b"]
var
# Out:
#    a  b   c
# 0  1  5   6
# 1  2  6   8
# 2  3  7  10
# 3  4  8  12

# %%
var["c"]= var["a"]-var["b"]
var
# Out:
#    a  b  c
# 0  1  5 -4
# 1  2  6 -4
# 2  3  7 -4
# 3  4  8 -4

# %%
var["c"]= var["a"]*var["b"]
var
# Out:
#    a  b   c
# 0  1  5   5
# 1  2  6  12
# 2  3  7  21
# 3  4  8  32

# %%
var["c"]= var["a"]/var["b"]
var
# Out:
#    a  b         c
# 0  1  5  0.200000
# 1  2  6  0.333333
# 2  3  7  0.428571
# 3  4  8  0.500000

# %%
var1= pd.DataFrame({"a":[10,21,13,19], "b":[15,26,37,98]})
var1
# Out:
#     a   b
# 0  10  15
# 1  21  26
# 2  13  37
# 3  19  98

# %%
var1["python"]= var1["a"]<=20
var1["python1"]= var1["b"]<=60
var1
# Out:
#     a   b  python  python1
# 0  10  15    True     True
# 1  21  26   False     True
# 2  13  37    True     True
# 3  19  98    True    False
