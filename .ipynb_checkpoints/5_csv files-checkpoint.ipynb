# %% [markdown]
# WRITE CSV FILE

# %%
import pandas as pd 
dis = {
    "a":[1,2,3,4,5],
    "b":[6,7,8,9,0],
    "c":[11,22,33,44,55]
}

d= pd.DataFrame(dis)


print(d)
d. to_csv("New_data1.csv", index= False)
# Out:
#    a  b   c
# 0  1  6  11
# 1  2  7  22
# 2  3  8  33
# 3  4  9  44
# 4  5  0  55
