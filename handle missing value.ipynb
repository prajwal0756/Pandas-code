# %% [markdown]
#  Dropna and Fillna

# %%
import pandas as pd 

var = pd.read_csv("/Users/prajwalsubedi/Desktop/Data science/Pandas code/credit(in).csv")
var
# Out:
#       transaction_id  amount transaction_hour merchant_category  \
# 0                  1   84.47               22       Electronics
# 1                  2  541.82                3            Travel
# 2                  3  237.01               17           Grocery
# 3                  4  164.33                4           Grocery
# 4                  5   30.53               15              Food
# ...              ...     ...              ...               ...
# 9995            9996  350.91               22              Food
# 9996            9997  410.04                5          Clothing
# 9997            9998  527.75               21       Electronics
# 9998            9999   91.20                2       Electronics
# 9999           10000   44.06                2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 0                     0.0                0.0                66.0
# ...

# %%
var.head()
# Out:
#    transaction_id  amount transaction_hour merchant_category  \
# 0               1   84.47               22       Electronics
# 1               2  541.82                3            Travel
# 2               3  237.01               17           Grocery
# 3               4  164.33                4           Grocery
# 4               5   30.53               15              Food
#
#    foreign_transaction  location_mismatch  device_trust_score  \
# 0                  0.0                0.0                66.0
# 1                  1.0                0.0                87.0
# 2                  0.0                0.0                49.0
# 3                  0.0                1.0                72.0
# 4                  0.0                0.0                79.0
#
#    velocity_last_24h  cardholder_age  is_fraud
# 0                3.0            40.0       NaN
# 1                1.0            64.0       0.0
# 2                1.0            61.0       0.0
# ...

# %%
var.shape
# Out:
# (10000, 10)

# %% [markdown]
# var.dropna(axis=0) axis =0 drops rows having missing value and 1 drops columns contains missing value
#
# and also if there is nan value in whole row then it can be removed by
# var.dropna(how="all")
#
# var.dropna(subset=["is_fraud"]) this removes the row of a columns whose contains numm value leaving other columns null value.
#
# var.dropna(inplace=True)
# var
# it revomes all null value and create new dataset. Just displays the updated DataFrame.

# %%
var.dropna(thresh=1)
var.head(15)
# Out:
#     transaction_id  amount transaction_hour merchant_category  \
# 1                2  541.82                3            Travel
# 2                3  237.01               17           Grocery
# 3                4  164.33                4           Grocery
# 4                5   30.53               15              Food
# 5                6   30.53               13          Clothing
# 6                7   10.77               18            Travel
# 7                8  362.02               13       Electronics
# 8                9  165.43                8           Grocery
# 9               10  221.63                5           Grocery
# 10              11    3.74               16           Grocery
# 11              12  630.64               18          Clothing
# 12              13  321.56               11          Clothing
# 14              15   36.12               15       Electronics
# 15              16   36.47               10          Clothing
# ...

# %%
var
# Out:
#       transaction_id  amount transaction_hour merchant_category  \
# 1                  2  541.82                3            Travel
# 2                  3  237.01               17           Grocery
# 3                  4  164.33                4           Grocery
# 4                  5   30.53               15              Food
# 5                  6   30.53               13          Clothing
# ...              ...     ...              ...               ...
# 9995            9996  350.91               22              Food
# 9996            9997  410.04                5          Clothing
# 9997            9998  527.75               21       Electronics
# 9998            9999   91.20                2       Electronics
# 9999           10000   44.06                2          Clothing
#
#       foreign_transaction  location_mismatch  device_trust_score  \
# 1                     1.0                0.0                87.0
# ...
