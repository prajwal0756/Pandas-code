# %% [markdown]
# Series
# -- It is a one dimensional array that is capable of storing various data types.

# %%
import numpy as np

# %%
import pandas as pd

# %%
x= [1,2,3,4,5]

var = pd.Series(x)
print(var)
print(type(var))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
dict = {"name": ['python', 'c', 'c++','java'], "por":[4,5,6,7], "rank": ['0','9','8','7']}

var1 = pd.Series(dict)
print(var1)
# Out:
# name    [python, c, c++, java]
# por               [4, 5, 6, 7]
# rank              [0, 9, 8, 7]
# dtype: object

# %%
s= pd.Series(10)

print(s)
# Out:
# 0    10
# dtype: int64

# %% [markdown]
# When we add to series in pandas we get nan values or missing values but in numpy it gernerate error as called broadcasting error.

# %%
s1 = pd.Series(7, index=[1,2,3,4,5])
s2 = pd.Series(7, index=[1,2,3])

print(s1+s2)
# Out:
# 1    14.0
# 2    14.0
# 3    14.0
# 4     NaN
# 5     NaN
# dtype: float64
